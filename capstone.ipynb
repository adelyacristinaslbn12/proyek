# %% [markdown]
# <a href="https://colab.research.google.com/github/adelyacristinaslbn12/proyek/blob/main/capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Untuk pengolahan data
import pandas as pd
import numpy as np
from zipfile import ZipFile
from pathlib import Path

# Untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_palette('Set1')
sns.set()

# Untuk pemodelan
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Untuk menghilangkan warnings saat plotting seaborn
import warnings
warnings.filterwarnings('ignore')

# Untuk mengupload file
from google.colab import files

# %%
# Upload semua dataset yang dipakai
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb0c1a7c-5e7d-4d95-96bd-126ec8176918" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb0c1a7c-5e7d-4d95-96bd-126ec8176918">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Menyimpan masing-masing dataset kedalam variabel
rating = pd.read_csv('/content/dataset - dataset_clean (1).csv')

# %%
# Melihat gambaran data rating

rating.head(5)
# Out:
#    Unnamed: 0                                           imageUrl  \
# 0           0  https://lh5.googleusercontent.com/p/AF1QipNqb2...
# 1           1  https://lh5.googleusercontent.com/p/AF1QipOn3h...
# 2           2  https://lh5.googleusercontent.com/p/AF1QipOWuk...
# 3           3  https://lh5.googleusercontent.com/p/AF1QipOeMX...
# 4           4  https://lh5.googleusercontent.com/p/AF1QipOD1-...
#
#                              title totalScore  reviewsCount  \
# 0       Taman Mini Indonesia Indah        4.6        164271
# 1  Taman Nasional Kepulauan Seribu        4.6           555
# 2             Pantai Pasir Perawan        4.8           717
# 3                     Wisata pulau        4.6           441
# 4        Wisata pantai. Pulau pari        4.6           862
#
#                            state                                city  cityTag  \
# 0  Daerah Khusus Ibukota Jakarta                  Kota Jakarta Timur  jakarta
# ...

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    574 non-null    int64
#  1   imageUrl      574 non-null    object
#  2   title         574 non-null    object
#  3   totalScore    574 non-null    object
#  4   reviewsCount  574 non-null    int64
#  5   state         574 non-null    object
#  6   city          574 non-null    object
#  7   cityTag       574 non-null    object
#  8   phone         574 non-null    object
#  9   categoryName  574 non-null    object
#  10  description   574 non-null    object
#  11  placeId       574 non-null    object
#  12  location/lat  574 non-null    float64
#  13  location/lng  574 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 62.9+ KB
